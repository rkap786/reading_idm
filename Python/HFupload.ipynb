# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
import pandas as pd
from datasets import load_dataset, Dataset
f= pd.read_csv("/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/Data/Processed/data_qual_info.csv")
dataset = Dataset.from_pandas(f)

# Save to a Hugging Face dataset repo
dataset.push_to_hub("domingue-lab/reading_idm", "data_qual_info")


f= pd.read_csv("/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/Data/Processed/data_passage_ques_options_pv.csv")
dataset = Dataset.from_pandas(f)

# Save to a Hugging Face dataset repo
dataset.push_to_hub("domingue-lab/reading_idm", "data_passage_ques_options_pv")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/6.88k [00:00<?, ?B/s]
# ...
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/6.89k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/domingue-lab/reading_idm/commit/8331926aac32112268d051b2946129d80145d9a7', commit_message='Upload dataset', commit_description='', oid='8331926aac32112268d051b2946129d80145d9a7', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/domingue-lab/reading_idm', endpoint='https://huggingface.co', repo_type='dataset', repo_id='domingue-lab/reading_idm'), pr_revision=None, pr_num=None)

# %%
from datasets import load_dataset, Dataset
ds = load_dataset("domingue-lab/reading_idm", split="train")
# Out:
# README.md:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1053 [00:00<?, ? examples/s]

# %%
ds
# Out:
# Dataset({
#     features: ['pdfname', 'PassNumUnq', 'Passage', 'QNoUnq', 'QuestionText', 'option_correct_ans', 'option_distractor1', 'option_distractor2', 'option_distractor3', 'pVal', 'question_correct_ans', 'question_dis1', 'question_dis2', 'question_dis3', 'psg_question_correct_ans', 'psg_question_dis1', 'psg_question_dis2', 'psg_question_dis3'],
#     num_rows: 1053
# })
