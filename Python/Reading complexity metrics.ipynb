# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#https://pypi.org/project/py-readability-metrics/
# !pip install py-readability-metrics
# !python -m nltk.downloader punkt
from readability import Readability
import numpy as np
import nltk
nltk.download('punkt_tab')
# Out:
# ...
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
#  Gunning Fog Index. It is a weighted average of the number of words per sentence, and the number of long words per word.
#
#  The Dale–Chall readability formula is a readability test that provides a numeric gauge of the comprehension difficulty that readers come upon when reading a text. It uses a list of 3000 words that groups of fourth-grade American students could reliably understand, considering any word not on that list to be difficult.
#
# automated readability index (ARI):  approximate representation of the US grade level needed to comprehend the text. It uses number of letters, number of words, and number of sentences in text
#
# Linsear Write - readability or grade level of text using easy or hard words, when easiness is defined by number of syllables in word
#
# SMOG - count of polysyllabic words
#
# SPACHE-  grade level based on average sentence length & complexity of text

# %%
import pandas as pd
file= pd.read_csv("/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/Data/Processed/Datacombined_clean_passages.csv")

# %%
file.head()
# Out:
#                       pdfname                    PassNumUnq  \
# 0  2019-released-items-ela-g4  2019-released-items-ela-g4.1
# 1  2019-released-items-ela-g4  2019-released-items-ela-g4.2
# 2  2019-released-items-ela-g5  2019-released-items-ela-g5.1
# 3  2019-released-items-ela-g5  2019-released-items-ela-g5.2
# 4  2019-released-items-ela-g5  2019-released-items-ela-g5.3
#
#                                              Passage  PassageWordCount  \
# 0   "No one but a man can do this," the business ...             451.0
# 1   King Tiger thought he was the greatest tiger ...             580.0
# 2   In the days when farmers worked with ox and s...             736.0
# 3   In a valley in the highlands of Scotland, the...             816.0
# 4   "Come," Wangari's mother called. She beckoned...             577.0
#
#   PassageLexile PassageFK                                     BoxTextPassage  \
# 0          810L       6.7  controversial = a topic that causes an argumen...
# ...

# %%
# file.columns
# text=file['Passage'][21]
# file.shape
# Out:
# (194, 16)

# %%
# text= file['Passage'][2]
# print(text)
# print(len(text.split()))
# r = Readability(text)
# r.flesch_kincaid()
# Out:
#  In the days when farmers worked with ox and sled and cut the dark with lantern light, there lived a boy who loved snow more than anything in the world. Willie Bentley's happiest days were snowstorm days. He watched snowflakes on his mittens, on the dried grass of Vermont farm fields, on the dark metal handle of the barn door. He said snow was as beautiful as butterflies, or apple blossoms.
#  He could net butterflies and show them to his older brother, Charlie. He could pick apple blossoms and take them to his mother. But he could not share snowflakes because he could not save them.
#  When his mother gave him an old microscope, he used it to look at flowers, raindrops, and blades of grass. Best of all, he used it to look at snow. While other children built forts and pelted snowballs at roosting crows, Willie was catching snowflakes. Day after stormy day he studied the icy crystals.
# ...

# %%
length= len(file)
print(length)
fk=[]
passage_len=[]
f= []
# gf=[]
# cl= []
# dale_chall=[]
# ari=[]
# linsear_write=[]
# smog=[]
# spache=[]

for i in range(length):
  text= file['Passage'][i]
  # print(i)
  if isinstance(text, str)==True:
    passage_len.append(len(text.split()))
    if len(text.split())<100:
      fk.append(np.nan)
      f.append(np.nan)
      # gf.append(np.nan)
      # cl.append(np.nan)
      # dale_chall.append(np.nan)
      # ari.append(np.nan)
      # linsear_write.append(np.nan)
      # smog.append(np.nan)
      # spache.append
      continue
    r = Readability(text)
    out = r.flesch_kincaid()
    fk.append(out.score)
    out= r.flesch()
    f.append(out.score)
    # out= r.gunning_fog()
    # gf.append(out.score)
    # out= r.coleman_liau()
    # cl.append(out.score)
    # out= r.dale_chall()
    # dale_chall.append(out.score)
    # out= r.ari()
    # ari.append(out.score)
    # out= r.linsear_write()
    # linsear_write.append(out.score)
    # out= r.smog()
    # smog.append(out.score)
    # out= r.spache()
    # spache.append(out.score)
# Out:
# 194

# %%
print(fk)
print(f)
# print(gf)
# print(cl)
# print(dale_chall)
# print(ari)
# print(linsear_write)
# print(smog)
# print(spache)
# Out:
# [6.855191570881228, 2.7655226229508223, 4.683676394059486, 5.100558115719405, 4.294900129892412, 6.0526390580592775, 7.0443959243085885, 8.26526625386997, 4.37944682221298, 7.074605881121183, 5.309999052256224, 4.900531343283582, 3.538477207330004, 6.7731159420289835, 5.973636363636363, 2.4835128596893306, 4.545629626817512, 6.725147732863764, 5.248909244815287, 7.852489887908774, 7.5287312200426975, 6.751318181818181, 9.617383066434122, 5.295609639866566, 5.241726296958856, 5.726838405797107, 6.1461123304970116, 7.719862982929026, 6.111257398236507, 7.6346012269938655, 7.7402285115304, 10.774550746268655, 1.7985470085470112, 6.6416294555425, 3.8466666666666676, 5.141132431324316, 5.998264755166641, 4.684114879147138, 2.370906688687036, 4.4806557070801425, 2.831723377629462, 3.461870814678761, 6.664659642881578, 6.078988031026867, 5.257724867724871, 4.906243386243386, 6.138594722162626, 5.106634721600241, 5.867102334895435, 5.808791171109387, 6.843927381806804, 8.135089455795015, 7.6
# ...

# %%
# text= file['Passage'][2]
# r = Readability(text)
# fk = r.flesch_kincaid()
# print(fk.score)
# print(fk.grade_level)
# Out:
# 4.683676394059486
# 5

# %%
file['fk']=fk
file['passage_len']=passage_len
file['fk'].isna().sum()
file.to_csv('/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/Data/Processed/Datacombined_clean_passages_fk_py.csv')

# %%
file.head()
# Out:
#                       pdfname                    PassNumUnq  \
# 0  2019-released-items-ela-g4  2019-released-items-ela-g4.1
# 1  2019-released-items-ela-g4  2019-released-items-ela-g4.2
# 2  2019-released-items-ela-g5  2019-released-items-ela-g5.1
# 3  2019-released-items-ela-g5  2019-released-items-ela-g5.2
# 4  2019-released-items-ela-g5  2019-released-items-ela-g5.3
#
#                                              Passage  PassageWordCount  \
# 0   "No one but a man can do this," the business ...             451.0
# 1   King Tiger thought he was the greatest tiger ...             580.0
# 2   In the days when farmers worked with ox and s...             736.0
# 3   In a valley in the highlands of Scotland, the...             816.0
# 4   "Come," Wangari's mother called. She beckoned...             577.0
#
#   PassageLexile  PassageFK                                     BoxTextPassage  \
# 0          810L        6.7  controversial = a topic that causes an argumen...
# ...
