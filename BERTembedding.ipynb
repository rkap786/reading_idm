# %% [markdown]
# <a href="https://colab.research.google.com/github/rkap786/reading_idm/blob/main/BERTembedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import transformers
import torch

#*** pretrained_model_vectorizer.py
# Library which includes all code that involves the use of pretrained
# models for contextualization
# Functions:
#    vectorize_with_pretrained_embeddings(sentences, labels): Given a list of text examples,
#    produces embeddings of dim 768 for each example
#***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
f= pd.read_csv("https://raw.githubusercontent.com/rkap786/reading_idm/main/Data/data_passage_ques_options_pv.csv?token=GHSAT0AAAAAACTDOKWOF4W2DBVQWTBZLQIWZUPDLSA")

# %%
question= f['QuestionText']
option1= f['Option1']
option2= f['Option2']
option3= f['Option3']
option4= f['Option4']

# %%
def vectorize_with_pretrained_embeddings(sentences):
  """
  Produces a tensor containing a BERT embedding for each sentence in the dataset or in a
  batch
  Args:
    sentences: List of sentences of length n
  Returns:
    embeddings: A 2D torch array containing embeddings for each of the n sentences (n x d)
                where d = 768
  """

  tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-cased')
  pretrained_model = transformers.BertModel.from_pretrained('bert-base-cased', output_hidden_states=False)
  pretrained_model.eval()
  embeddings = []
  for sentence in sentences:
    with_tags = "[CLS] " + sentence + " [SEP]"
    tokenized_sentence = tokenizer.tokenize(with_tags)
    # print(tokenized_sentence)
    # print(len(tokenized_sentence))
    indices_from_tokens = tokenizer.convert_tokens_to_ids(tokenized_sentence)
    segments_ids = [1] * len(indices_from_tokens)
    tokens_tensor = torch.tensor([indices_from_tokens])
    segments_tensors = torch.tensor([segments_ids])
    # print(indices_from_tokens)
    # print(tokens_tensor)
    # print(segments_tensors)
    with torch.no_grad():
      outputs = pretrained_model(tokens_tensor, segments_tensors)[0] # The output is the
      #last hidden state of the pretrained model of shape 1 x sentence_length x BERT embedding_length
      embeddings.append(torch.mean(outputs, dim = 1))# we average across the embedding length
      #dimension to produce constant sized tensors
  print(embeddings[0].shape)
  embeddings = torch.cat(embeddings, dim = 0)
  print('Shape of embeddings tensor (n x d = 768): ', embeddings.shape)
  return embeddings.cpu().detach().numpy()

# %%
# Out:
#                       pdfname                    PassNumUnq  \
# 0  2019-released-items-ela-g4  2019-released-items-ela-g4.1
# 1  2019-released-items-ela-g4  2019-released-items-ela-g4.1
# 2  2019-released-items-ela-g4  2019-released-items-ela-g4.1
# 3  2019-released-items-ela-g4  2019-released-items-ela-g4.1
# 4  2019-released-items-ela-g4  2019-released-items-ela-g4.1
#
#                                              Passage  \
# 0   "No one but a man can do this," the business ...
# 1   "No one but a man can do this," the business ...
# 2   "No one but a man can do this," the business ...
# 3   "No one but a man can do this," the business ...
# 4   "No one but a man can do this," the business ...
#
#                             QNoUnq  \
# 0  2019-released-items-ela-g4.1.13
# 1  2019-released-items-ela-g4.1.14
# 2  2019-released-items-ela-g4.1.15
# 3  2019-released-items-ela-g4.1.16
# 4  2019-released-items-ela-g4.1.17
#
#                                         QuestionText  \
# 0   What does the phrase "set out" mean as it is ...
# 1   Read this sentence from paragraph 6.\n *Trave...
# 2   How does the author organize the information ...
# 3   What does the word "journalism" mean as it is...
# 4   Which detail from the article does the map su...
#
#                                              Option1  \
# 0                               grabbed her suitcase
# 1  It shows how she is the same as the character ...
# 2       by listing events in the order they happened
# 3                             writing for newspapers
# 4  "Start the man, and I'll start the same day. ....
#
#                                              Option2  \
# 0                                  began her journey
# 1       It shows one way to help her reach her goal.
# 2  by comparing and contrasting the places Nellie...
# 3                                traveling for women
# 4   "She reached New York in 4% days.' (paragraph 7)
#
#                                              Option3  \
# 0                                      accepted work
# 1  It shows a young reporter exploring the world ...
# 2  by showing what caused Nellie to want to take ...
# 3                                 finding adventures
# 4             "She met her challenge!" (paragraph 8)
#
#                                              Option4  pVal
# 0                                    started writing  0.85
# 1  It shows that a young woman taking a trip alon...  0.51
# 2  by stating how the problem of traveling so far...  0.61
# 3                               discovering opinions  0.62
# 4  "She reported to her readers what she saw, tho...  0.38

# %%
#Test sentences. To test, run 'python pretrained_model_vectorizer.py' at the command line
#sentences = ["The boy is running", "The dog has been barking for the whole evening"]
#To use with real data, import pretrained_model_vectorizer, then call
#'vectorize_with_pretrained_embeddings' on your list of sentences to embed
question.embed= vectorize_with_pretrained_embeddings(question)
# Out:
# torch.Size([1, 768])
# Shape of embeddings tensor (n x d = 768):  torch.Size([1116, 768])

# %%
optionembed1= vectorize_with_pretrained_embeddings(option1)
optionembed2= vectorize_with_pretrained_embeddings(option2)
optionembed3= vectorize_with_pretrained_embeddings(option3)
optionembed4= vectorize_with_pretrained_embeddings(option4)
# Out:
# torch.Size([1, 768])
# Shape of embeddings tensor (n x d = 768):  torch.Size([1116, 768])
# torch.Size([1, 768])
# Shape of embeddings tensor (n x d = 768):  torch.Size([1116, 768])
# torch.Size([1, 768])
# Shape of embeddings tensor (n x d = 768):  torch.Size([1116, 768])
# torch.Size([1, 768])
# Shape of embeddings tensor (n x d = 768):  torch.Size([1116, 768])

# %%
import numpy as np
from numpy import savetxt
df= pd.DataFrame(question.embed)
df.to_csv('/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/question_embed.csv')

df= pd.DataFrame(optionembed1)
df.to_csv('/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/option_embed1.csv')

df= pd.DataFrame(optionembed2)
df.to_csv('/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/option_embed2.csv')

df= pd.DataFrame(optionembed3)
df.to_csv('/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/option_embed3.csv')

df= pd.DataFrame(optionembed4)
df.to_csv('/content/drive/MyDrive/0. Projects - Stanford/Item generation/Data/option_embed4.csv')

#np.savetxt('/Users/radhika/Downloads/question_embed.csv', question.embed, delimiter=',')
#np.save(question.embed,)

# %%
df
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.330693  0.038969  0.069046  0.141347  0.562531 -0.034794 -0.045604
# 1     0.150200  0.274270 -0.039747  0.272531  0.666258 -0.126865  0.024354
# 2     0.316193 -0.114018 -0.007403  0.150899  0.482411 -0.054715  0.255445
# 3     0.451735 -0.035361  0.060584  0.046701  0.494822  0.024858  0.058867
# 4     0.375125 -0.001411  0.016060 -0.089303  0.024385  0.141236  0.317772
# ...        ...       ...       ...       ...       ...       ...       ...
# 1111  0.374191 -0.092379  0.249997  0.309695  0.122369 -0.153756  0.123190
# 1112  0.197396 -0.015915  0.096769  0.203303  0.251318 -0.227677  0.172645
# 1113  0.297722 -0.003906  0.007676  0.123774  0.052911 -0.238047  0.119631
# 1114  0.408570  0.140626  0.007848  0.179747  0.132918 -0.180473  0.132025
# 1115  0.359874  0.065315 -0.030843  0.055246 -0.040103 -0.245964  0.142912
#
#            7         8         9    ...       758       759       760  \
# 0     0.071342 -0.053162 -0.217772  ...  0.317475  0.156087 -0.123962
# 1    -0.013578 -0.016012 -0.114078  ...  0.208553  0.335136 -0.002739
# 2     0.073818 -0.062459 -0.065642  ...  0.376271  0.203655 -0.218886
# 3     0.131332 -0.004860 -0.290856  ...  0.245316  0.166824 -0.153981
# 4     0.116051 -0.206724 -0.230045  ...  0.256846  0.177193 -0.099984
# ...        ...       ...       ...  ...       ...       ...       ...
# 1111  0.003419  0.053187  0.195876  ... -0.048363  0.057822 -0.082947
# 1112 -0.086674 -0.062594 -0.002558  ...  0.036880  0.011768  0.054642
# 1113  0.062502  0.060466  0.146408  ...  0.037549  0.198642 -0.075447
# 1114  0.076565 -0.043467  0.182478  ...  0.205288  0.061859 -0.020326
# 1115  0.123510 -0.234201  0.226448  ...  0.130560  0.093834  0.034256
#
#            761       762       763       764       765       766       767
# 0    -0.269952  0.094822  0.145907 -0.207998  0.324924  0.330233 -0.009789
# 1    -0.248087  0.044126  0.209430 -0.082822  0.187699  0.172975  0.142289
# 2    -0.109045  0.187939  0.178523 -0.090680  0.405097  0.209188 -0.032180
# 3    -0.259816 -0.038695  0.186564 -0.191631  0.309455  0.253131  0.001289
# 4    -0.219399  0.038975  0.209707 -0.124114  0.087240  0.294826  0.216154
# ...        ...       ...       ...       ...       ...       ...       ...
# 1111 -0.117225  0.034189 -0.216345 -0.063492  0.308002  0.208320 -0.122181
# 1112  0.074262  0.104311 -0.230042 -0.028243  0.311628 -0.011404 -0.008374
# 1113 -0.001407  0.087634 -0.141926 -0.089317  0.286568  0.183502 -0.043947
# 1114 -0.103721  0.089978 -0.167842 -0.041928  0.132927  0.166269 -0.081589
# 1115 -0.045818  0.187287 -0.172153 -0.091073  0.263691  0.038385 -0.068459
#
# [1116 rows x 768 columns]

# %%
df
# Out:
# (1116, 768)

# %%
question.embed
# Out:
# array([[ 0.33069327,  0.0389686 ,  0.06904568, ...,  0.3249241 ,
#          0.33023322, -0.00978899],
#        [ 0.15020001,  0.27427033, -0.03974681, ...,  0.18769884,
#          0.17297511,  0.14228924],
#        [ 0.31619295, -0.11401785, -0.00740315, ...,  0.40509737,
#          0.20918822, -0.03217997],
#        ...,
#        [ 0.29772183, -0.00390649,  0.00767591, ...,  0.28656772,
#          0.18350151, -0.04394712],
#        [ 0.4085702 ,  0.14062564,  0.00784751, ...,  0.13292709,
#          0.1662686 , -0.0815894 ],
#        [ 0.359874  ,  0.0653155 , -0.03084283, ...,  0.26369065,
#          0.03838476, -0.06845871]], dtype=float32)
